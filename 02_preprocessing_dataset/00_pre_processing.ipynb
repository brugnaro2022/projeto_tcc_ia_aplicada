# %% [markdown]
# <h4><b>Importação de Bibliotecas</b></h4>

# %%
import pandas as pd

import requests
import lzma
import json

# %% [markdown]
# <h4><b>Funções utilizadas </b></h4>

# %%
"""
    Função reutilizável para carregamento dos dados.
"""
def load_dataset(path, file_type):
    if file_type == 'json':
        return pd.read_json(path)
    elif file_type == 'csv':
        return pd.read_csv(path)
    else:
        return print('Erro ao carregar os dados')
    
def rename_features(dataset, renamed_columns, inplace, logs):
    if logs:
        print('-'*100)
        print('Renomeando features')
    """
    Parâmetro inplace modifica o dataframe ou series diretamente, sem criar um novo objeto. 
    As alterações são efetivadas diretamente no datasframe ou series em memória.
    """
    return dataset.rename(columns=renamed_columns, inplace=inplace)

def remove_features(dataset, features, inplace, logs):
    if logs:
        print('-'*100)
        print('Removendo features do dataset')
        
    return dataset.drop(columns=features, inplace=inplace)
    
def validate_numeric_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Verificando se existem registros não numéricos')
        print(f'Total de registros: {len(dataset[feature])}')
    
    """
    Parâmetro errors especifica como tratar erros que ocorrem durante a conversão. 
    Quando erros='coerce' é definido, qualquer valor que não possa ser convertido em um valor numérico 
    o tipo será substituído por NaN (não é um número).
    """
    numeric_data = pd.to_numeric(dataset[feature], errors='coerce')
    non_integers = dataset[feature][numeric_data.isna()]
    
    if logs:
        print(f'Total de registros não numéricos: {len(non_integers)}')
        print(f'Total de registros numéricos: {len(numeric_data) - len(non_integers)}')
    
        if len(non_integers) > 0:
            if logs:
                print('Lista registros não numéricos')
            print(non_integers)
        else:
            if logs:
                print('Não existem registros não numéricos')
        
def clean_non_numeric_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Limpando string X de registros não numéricos')
    return [str(item)[1:] if str(item).startswith('X') else item for item in dataset[feature]]

def convert_object_to_int(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Convertendo tipo de object para int')
    return pd.to_numeric(dataset[feature], errors='coerce').astype(int)

def checks_duplicate_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Verificando se existem registros duplicados na feature line_id')
    duplicates = dataset[dataset[feature].duplicated()]
    
    if logs:
        print(f'Existem {len(duplicates)} registros duplicados')

def show_duplicate_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Mostrando registros duplicados na feature line_id')
    duplicates = dataset[dataset[feature].duplicated()]
    
    if logs:
        if len(duplicates) > 0:
            print(duplicates['line_id'])
        else:
            print('Não existem registros duplicados a serem exibidos')

def sequencing_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Sequenciando registros pela feature line_id')
    return dataset.sort_values(by=feature).reset_index(drop=True)

def remove_duplicate_registers(dataset, feature, logs):
    if logs:
        print('-'*100)
        print('Removendo registros duplicados')
    return dataset.drop_duplicates(subset=[feature])

# %% [markdown]
# <h4><b>Coleta dos Dados</b></h4>
# <p>A coleta dos dados é automatizada, deste modo, disparamos uma requisição para cada dataset e o download é efetuado.</p>
# <p>São declaradas variáveis que recebem as definições de data inicial, data final, ano, mês. Uma lista é montada com range de dias.</p>
# <p>São declaradas variáveis que recebem os caminhos, que serão salvos os datasets.</p>
# <p>Datas dos datasets capturados:</p>
# <ul>
#     <li>Mês de Janeiro de 2023 - iniciando no dia 01 e finalizando do dia 31;</li>
#     <li>Mês de Junho de 2024 - iniciando no dia 05 e finalizando do dia 30.</li>
# </ul>

# %%
# 1-31 2023 01
# 5-30 2024 06
INITIAL_DATE = 5
FINAL_DATE = 30
YEAR = '2024'
MONTH = '06'
days_list = [f"{num:02}" for num in list(range(INITIAL_DATE, FINAL_DATE + 1))]
PATH_ORIGINALS_DATASETS = '/media/marcos/500GB/00_datasets/originals/'
PATH_INITIAL_PREPROCESSING_DATASETS = '/media/marcos/500GB/00_datasets/initial_preprocessing/'
PATH_CONCATENATED_DATASETS = '/media/marcos/500GB/00_datasets/concatenated/'
PATH_JOINED_DATASETS = '/media/marcos/500GB/00_datasets/joined/'

# %%
for day in days_list:
    print(f'Iniciando download, extração e salvamento dos datasets - data: {YEAR}/{MONTH}/{day}')
    list_datasets_names = [
        f'{YEAR}_{MONTH}_{day}_linhas',
        f'{YEAR}_{MONTH}_{day}_pontosLinha',
        f'{YEAR}_{MONTH}_{day}_tabelaLinha',
        f'{YEAR}_{MONTH}_{day}_trechosItinerarios',
        f'{YEAR}_{MONTH}_{day}_tabelaVeiculo'
    ]
    
    for dataset_name in list_datasets_names:
        url = f"https://dadosabertos.c3sl.ufpr.br/curitibaurbs/{dataset_name}.json.xz"
        response = requests.get(url)
        
        if response.status_code == 200:
            # Extraindo (descomprimindo) conteúdo do response
            decompressed_data = lzma.decompress(response.content)
            
            # Carregando conteúdo extraido em formato JSON
            data = json.loads(decompressed_data.decode('utf-8'))
            
            # Salvando arquivo do dataset, formato JSON, em diretório local
            with open(f'{PATH_ORIGINALS_DATASETS}{dataset_name}.json', 'w', encoding='utf-8') as json_file:
                json.dump(data, json_file, indent=4)
            # print(f"Dataset: {dataset_name} extraído e salvo com sucesso!")
        else:
            print(f"Falha ao extrair e salvar dataset. Status code: {response.status_code}")
    print(f'Finalização de download, extração e salvamento dos datasets - data: {YEAR}/{MONTH}/{day}')
    print('-'*100)
# Out:
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/05
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/05
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/06
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/06
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/07
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/07
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/08
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/08
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/09
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/09
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/10
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/10
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/11
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/11
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/12
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/12
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/13
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/13
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/14
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/14
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/15
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/15
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/16
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/16
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/17
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/17
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/18
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/18
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/19
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/19
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/20
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/20
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/21
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/21
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/22
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/22
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/23
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/23
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/24
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/24
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/25
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/25
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/26
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/26
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/27
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/27
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/28
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/28
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/29
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/29
# ----------------------------------------------------------------------------------------------------
# Iniciando download, extração e salvamento dos datasets - data: 2024/06/30
# Finalização de download, extração e salvamento dos datasets - data: 2024/06/30
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# <h4><b>Carregamento dos datasets</b></h4>
# <p>Efetuamos o carregamento dos datasets e submetemos os mesmos as etapas de pré-processamento.</p>

# %% [markdown]
# <h4><b>Etapas de pré-processamento</b></h4>
# <ul>
#     <li>Renomeando features;</li>
#     <li>Validando a feature line_id se ela contém apenas registros numéricos;</li>
#     <li>Na feature line_id durante o pré-processamento, foram encontrados registros não numéricos, contendo a string 'X 'número''. Realizamos procedimento de remover esta string 'X' e deixar somente o número;</li>
#     <li>Convertendo todos registros da feature line_id de object para int64;</li>
#     <li>Sequenciamento em ordem crescente dos registros, tendo por base a feature line_id;</li>
#     <li>Checagem de registros duplicados na feature line_id e remoção;</li>
#     <li>Merge dos datasets: Mês de Janeiro de 2023 - iniciando no dia 01 e finalizando do dia 31; </li>
#     <li>Merge dos datasets: Mês de Junho de 2024 - iniciando no dia 05 e finalizando do dia 30; </li>
#     <li>Carregando os dois datasets mergiados;</li>
#     <li>Concatenação dos datasets mergiados visando a geração de um único dataset.</li>
# </ul>

# %%
for day in days_list:
    CAPTURE_DATE = f'{YEAR}_{MONTH}_{day}'
    
    print('Carregando datasets')
    
    path = f"{PATH_ORIGINALS_DATASETS}{CAPTURE_DATE}_"
          
    linhas_df = load_dataset(f'{path}linhas.json', 'json')
    pontos_linha_df = load_dataset(f'{path}pontosLinha.json', 'json')
    veiculos_df = load_dataset(f'{path}tabelaVeiculo.json', 'json')
    tabela_linha_df = load_dataset(f'{path}tabelaLinha.json', 'json')
    trechos_itinerarios_df = load_dataset(f'{path}trechosItinerarios.json', 'json')
        
    print('Datasets carregados com sucesso!')

    print('--'*60)
    
    line_df = linhas_df.copy()
    
    line_df_renamed_columns = {
        'COD': 'line_id',
        'NOME': 'line_name',
        'NOME_COR': 'line_color',
        'CATEGORIA_SERVICO': 'line_category',
        'SOMENTE_CARTAO': 'line_payment_method'
    }
    print(f'Iniciando pre-processamento dataset line_df - data: {CAPTURE_DATE}')
    rename_features(line_df, line_df_renamed_columns, True, False)
    validate_numeric_registers(line_df, 'line_id', False)
    line_df['line_id'] = clean_non_numeric_registers(line_df, 'line_id', False)
    validate_numeric_registers(line_df, 'line_id', False)
    line_df['line_id'] = convert_object_to_int(line_df, 'line_id', False)
    line_df = sequencing_registers(line_df, 'line_id', False)
    checks_duplicate_registers(line_df, 'line_id', False)
    show_duplicate_registers(line_df, 'line_id', False)
    line_df = remove_duplicate_registers(line_df, 'line_id', False)
    checks_duplicate_registers(line_df, 'line_id', False)
    print(f'Finalizando pre-processamento dataset line_df - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    station_df = pontos_linha_df.copy()
    
    station_df_renamed_columns = {
        'NOME': 'station_name',
        'NUM': 'station_code',
        'LAT': 'station_initial_latitude',
        'LON': 'station_initial_longitude',
        'SEQ': 'station_sequence',
        'SENTIDO': 'station_direction',
        'TIPO': 'station_type',
        'COD': 'line_id',
    }
    print(f'Iniciando pre-processamento dataset station_df - data: {CAPTURE_DATE}')
    rename_features(station_df, station_df_renamed_columns, True, False)
    remove_features(station_df, ['GRUPO','ITINERARY_ID'], True, False)
    validate_numeric_registers(station_df, 'line_id', False)
    station_df['line_id'] = clean_non_numeric_registers(station_df, 'line_id', False)
    validate_numeric_registers(station_df, 'line_id', False)
    station_df['line_id'] = convert_object_to_int(station_df, 'line_id', False)
    station_df = sequencing_registers(station_df, 'line_id', False)
    checks_duplicate_registers(station_df, 'line_id', False)
    show_duplicate_registers(station_df, 'line_id', False)
    station_df = remove_duplicate_registers(station_df, 'line_id', False)
    checks_duplicate_registers(station_df, 'line_id', False)
    print(f'Finalizando pre-processamento dataset station_df - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    vehicle_df = veiculos_df.copy()
    
    vehicle_df_renamed_columns = { 
        'VEICULO': 'vehicle_plate', 
        'HORARIO': 'vehicle_time',
        'COD_LINHA': 'line_id'
    }
    
    vehicle_df_columns_to_remove = ['NOME_LINHA','TABELA', 'COD_PONTO']
    
    print(f'Iniciando pre-processamento dataset vehicle_df - data: {CAPTURE_DATE}')
    rename_features(vehicle_df, vehicle_df_renamed_columns, True, False)
    remove_features(vehicle_df, vehicle_df_columns_to_remove, True, False)
    validate_numeric_registers(vehicle_df, 'line_id', False)
    vehicle_df['line_id'] = clean_non_numeric_registers(vehicle_df, 'line_id', False)
    validate_numeric_registers(vehicle_df, 'line_id', False)
    vehicle_df['line_id'] = convert_object_to_int(vehicle_df, 'line_id', False)
    vehicle_df = sequencing_registers(vehicle_df, 'line_id', False)
    checks_duplicate_registers(vehicle_df, 'line_id', False)
    show_duplicate_registers(vehicle_df, 'line_id', False)
    vehicle_df = remove_duplicate_registers(vehicle_df, 'line_id', False)
    checks_duplicate_registers(vehicle_df, 'line_id', False)
    print(f'Finalizando pre-processamento dataset vehicle_df - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    accessibility_info_df = tabela_linha_df.copy()
    
    accessibility_info_df_renamed_columns = {
        'ADAPT': 'accessibility_info_eletric_ramp',
        'HORA': 'accessibility_info_time',
        'DIA': 'accessibility_info_day',
        'COD': 'line_id'
    }
    accessibility_info_df_columns_to_remove = ['PONTO','NUM','TABELA']
    
    print(f'Iniciando pre-processamento dataset accessibility_info_df - data: {CAPTURE_DATE}')
    rename_features(accessibility_info_df, accessibility_info_df_renamed_columns, True, False)
    remove_features(accessibility_info_df, accessibility_info_df_columns_to_remove, True, False)
    validate_numeric_registers(accessibility_info_df, 'line_id', False)
    accessibility_info_df['line_id'] = clean_non_numeric_registers(accessibility_info_df, 'line_id', False)
    validate_numeric_registers(accessibility_info_df, 'line_id', False)
    accessibility_info_df['line_id'] = convert_object_to_int(accessibility_info_df, 'line_id', False)
    accessibility_info_df = sequencing_registers(accessibility_info_df, 'line_id', False)
    checks_duplicate_registers(accessibility_info_df, 'line_id', False)
    show_duplicate_registers(accessibility_info_df, 'line_id', False)
    accessibility_info_df = remove_duplicate_registers(accessibility_info_df, 'line_id', False)
    checks_duplicate_registers(accessibility_info_df, 'line_id', False)
    print(f'Finalizando pre-processamento dataset accessibility_info_df - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    itinerary_df = trechos_itinerarios_df.copy()
    
    itinerary_df_renamed_columns = { 
        'NOME_EMPRESA': 'itinerary_company_name',
        'COD_ITINERARIO': 'itinerary_code',
        'PTO_ESPECIAL': 'itinerary_special_line',
        'COD_LINHA': 'line_id',
    }
    
    itinerary_df_columns_to_remove = [
        'NOME_LINHA',
        'COD_CATEGORIA',
        'NOME_CATEGORIA',
        'COD_EMPRESA',
        'COD_PTO_PARADA_TH',
        'NOME_PTO_PARADA_TH',
        'NOME_PTO_ABREVIADO',
        'SEQ_PTO_ITI_TH',
        'NOME_ITINERARIO',
        'COD_PTO_TRECHO_A',
        'SEQ_PONTO_TRECHO_A',
        'COD_PTO_TRECHO_B',
        'SEQ_PONTO_TRECHO_B',
        'EXTENSAO_TRECHO_A_ATE_B',
        'TIPO_TRECHO',
        'STOP_CODE',
        'STOP_NAME',
        'CODIGO_URBS'
    ]
    
    print(f'Iniciando pre-processamento dataset itinerary_df - data: {CAPTURE_DATE}')
    rename_features(itinerary_df, itinerary_df_renamed_columns, True, False)
    remove_features(itinerary_df, itinerary_df_columns_to_remove, True, False)
    validate_numeric_registers(itinerary_df, 'line_id', False)
    itinerary_df['line_id'] = clean_non_numeric_registers(itinerary_df, 'line_id', False)
    validate_numeric_registers(itinerary_df, 'line_id', False)
    itinerary_df['line_id'] = convert_object_to_int(itinerary_df, 'line_id', False)
    itinerary_df = sequencing_registers(itinerary_df, 'line_id', False)
    checks_duplicate_registers(itinerary_df, 'line_id', False)
    show_duplicate_registers(itinerary_df, 'line_id', False)
    itinerary_df = remove_duplicate_registers(itinerary_df, 'line_id', False)
    checks_duplicate_registers(itinerary_df, 'line_id', False)
    print(f'Finalizando pre-processamento dataset itinerary_df - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    print(f'Iniciando merge de todos datasets inicialmente pre-processados - data: {CAPTURE_DATE}')
    line_station_df = pd.merge(line_df, station_df, on='line_id')
    line_station_vehicle_df = pd.merge(line_station_df, vehicle_df, on='line_id')
    line_station_vehicle_accessibility_info_df = pd.merge(line_station_vehicle_df, accessibility_info_df, on='line_id')
    line_station_vehicle_accessibility_info_itinerary_df = pd.merge(line_station_vehicle_accessibility_info_df, itinerary_df, on='line_id')
    df = line_station_vehicle_accessibility_info_itinerary_df
    print(f'Merge finalizado - data: {CAPTURE_DATE}')
    
    print('--'*60)
    
    print(f'Salvando dataset - data: {YEAR}_{MONTH}_{day}')
    dataset_file_name = f'merged_dataset_{YEAR}_{MONTH}_{day}_.csv'
    df.to_csv(f'{PATH_INITIAL_PREPROCESSING_DATASETS}{dataset_file_name}', index=False)
    print('Dataset salvo com sucesso')
# Out:
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_05
# Finalizando pre-processamento dataset line_df - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_05
# Finalizando pre-processamento dataset station_df - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_05
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_05
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_05
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_05
# Merge finalizado - data: 2024_06_05
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_05
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_06
# Finalizando pre-processamento dataset line_df - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_06
# Finalizando pre-processamento dataset station_df - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_06
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_06
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_06
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_06
# Merge finalizado - data: 2024_06_06
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_06
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_07
# Finalizando pre-processamento dataset line_df - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_07
# Finalizando pre-processamento dataset station_df - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_07
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_07
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_07
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_07
# Merge finalizado - data: 2024_06_07
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_07
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_08
# Finalizando pre-processamento dataset line_df - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_08
# Finalizando pre-processamento dataset station_df - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_08
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_08
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_08
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_08
# Merge finalizado - data: 2024_06_08
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_08
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_09
# Finalizando pre-processamento dataset line_df - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_09
# Finalizando pre-processamento dataset station_df - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_09
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_09
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_09
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_09
# Merge finalizado - data: 2024_06_09
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_09
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_10
# Finalizando pre-processamento dataset line_df - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_10
# Finalizando pre-processamento dataset station_df - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_10
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_10
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_10
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_10
# Merge finalizado - data: 2024_06_10
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_10
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_11
# Finalizando pre-processamento dataset line_df - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_11
# Finalizando pre-processamento dataset station_df - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_11
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_11
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_11
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_11
# Merge finalizado - data: 2024_06_11
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_11
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_12
# Finalizando pre-processamento dataset line_df - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_12
# Finalizando pre-processamento dataset station_df - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_12
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_12
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_12
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_12
# Merge finalizado - data: 2024_06_12
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_12
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_13
# Finalizando pre-processamento dataset line_df - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_13
# Finalizando pre-processamento dataset station_df - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_13
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_13
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_13
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_13
# Merge finalizado - data: 2024_06_13
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_13
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_14
# Finalizando pre-processamento dataset line_df - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_14
# Finalizando pre-processamento dataset station_df - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_14
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_14
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_14
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_14
# Merge finalizado - data: 2024_06_14
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_14
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_15
# Finalizando pre-processamento dataset line_df - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_15
# Finalizando pre-processamento dataset station_df - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_15
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_15
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_15
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_15
# Merge finalizado - data: 2024_06_15
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_15
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_16
# Finalizando pre-processamento dataset line_df - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_16
# Finalizando pre-processamento dataset station_df - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_16
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_16
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_16
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_16
# Merge finalizado - data: 2024_06_16
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_16
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_17
# Finalizando pre-processamento dataset line_df - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_17
# Finalizando pre-processamento dataset station_df - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_17
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_17
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_17
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_17
# Merge finalizado - data: 2024_06_17
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_17
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_18
# Finalizando pre-processamento dataset line_df - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_18
# Finalizando pre-processamento dataset station_df - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_18
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_18
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_18
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_18
# Merge finalizado - data: 2024_06_18
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_18
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_19
# Finalizando pre-processamento dataset line_df - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_19
# Finalizando pre-processamento dataset station_df - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_19
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_19
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_19
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_19
# Merge finalizado - data: 2024_06_19
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_19
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_20
# Finalizando pre-processamento dataset line_df - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_20
# Finalizando pre-processamento dataset station_df - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_20
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_20
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_20
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_20
# Merge finalizado - data: 2024_06_20
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_20
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_21
# Finalizando pre-processamento dataset line_df - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_21
# Finalizando pre-processamento dataset station_df - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_21
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_21
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_21
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_21
# Merge finalizado - data: 2024_06_21
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_21
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_22
# Finalizando pre-processamento dataset line_df - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_22
# Finalizando pre-processamento dataset station_df - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_22
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_22
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_22
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_22
# Merge finalizado - data: 2024_06_22
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_22
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_23
# Finalizando pre-processamento dataset line_df - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_23
# Finalizando pre-processamento dataset station_df - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_23
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_23
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_23
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_23
# Merge finalizado - data: 2024_06_23
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_23
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_24
# Finalizando pre-processamento dataset line_df - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_24
# Finalizando pre-processamento dataset station_df - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_24
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_24
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_24
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_24
# Merge finalizado - data: 2024_06_24
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_24
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_25
# Finalizando pre-processamento dataset line_df - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_25
# Finalizando pre-processamento dataset station_df - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_25
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_25
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_25
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_25
# Merge finalizado - data: 2024_06_25
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_25
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_26
# Finalizando pre-processamento dataset line_df - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_26
# Finalizando pre-processamento dataset station_df - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_26
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_26
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_26
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_26
# Merge finalizado - data: 2024_06_26
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_26
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_27
# Finalizando pre-processamento dataset line_df - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_27
# Finalizando pre-processamento dataset station_df - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_27
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_27
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_27
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_27
# Merge finalizado - data: 2024_06_27
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_27
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_28
# Finalizando pre-processamento dataset line_df - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_28
# Finalizando pre-processamento dataset station_df - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_28
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_28
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_28
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_28
# Merge finalizado - data: 2024_06_28
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_28
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_29
# Finalizando pre-processamento dataset line_df - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_29
# Finalizando pre-processamento dataset station_df - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_29
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_29
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_29
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_29
# Merge finalizado - data: 2024_06_29
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_29
# Dataset salvo com sucesso
# Carregando datasets
# Datasets carregados com sucesso!
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset line_df - data: 2024_06_30
# Finalizando pre-processamento dataset line_df - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset station_df - data: 2024_06_30
# Finalizando pre-processamento dataset station_df - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset vehicle_df - data: 2024_06_30
# Finalizando pre-processamento dataset vehicle_df - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset accessibility_info_df - data: 2024_06_30
# Finalizando pre-processamento dataset accessibility_info_df - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando pre-processamento dataset itinerary_df - data: 2024_06_30
# Finalizando pre-processamento dataset itinerary_df - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Iniciando merge de todos datasets inicialmente pre-processados - data: 2024_06_30
# Merge finalizado - data: 2024_06_30
# ------------------------------------------------------------------------------------------------------------------------
# Salvando dataset - data: 2024_06_30
# Dataset salvo com sucesso

# %% [markdown]
# <h4><b>Concatenando datasets mergiados</b></h4>

# %%
df_list = []
for day in days_list:
    df = pd.read_csv(f'{PATH_INITIAL_PREPROCESSING_DATASETS}merged_dataset_{YEAR}_{MONTH}_{day}_.csv')
    df_list.append(df)
    
df_concat = pd.concat(df_list, ignore_index=True)
df_concat.to_csv(f'{PATH_CONCATENATED_DATASETS}concatenated_dataset_{YEAR}_{MONTH}.csv', index=False)

# %% [markdown]
# <h4><b>Reunindo datasets pré-processados, mergiados e concatenados visando a geração de um único dataset.</b></h4>
# <p>Geração de um dataset único, formado pela junção de todos datasets.</p>

# %%
df_concatenated_dataset_list = []
month_list = [
    {'year': '2023', 'month': '01'},
    {'year': '2024', 'month': '06'}
]

for month in month_list:
    df_concatenated = pd.read_csv(f'{PATH_CONCATENATED_DATASETS}concatenated_dataset_{month["year"]}_{month["month"]}.csv')
    df_concatenated_dataset_list.append(df_concatenated)

df_joined = pd.concat(df_concatenated_dataset_list, ignore_index=True)
df_joined.to_csv(f'{PATH_JOINED_DATASETS}joined_dataset.csv', index=False)

# %%
df = load_dataset(f'{PATH_JOINED_DATASETS}joined_dataset.csv', 'csv')
